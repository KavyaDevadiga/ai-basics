# %% [markdown]
# Named entity tags return the type of the named entity. Example:
# Person Eg: Kavya
# Place or Location Eg: India
# Date Eg: 09/09/2000
# Time Eg: 4:30
# Money Eg: 1 Rupee
# Organisation: Nvidia
# Percent Eg: 20%

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
words = nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /home/kavya/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /home/kavya/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
tag_elements = nltk.pos_tag(words)

# %%
# %pip install numpy
# %pip install svgling
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])

# %%
ne_rec = nltk.ne_chunk(tag_elements).pformat()

# %%
ne_rec
# Out:
# '(S\n  The/DT\n  (ORGANIZATION Eiffel/NNP Tower/NNP)\n  was/VBD\n  built/VBN\n  from/IN\n  1887/CD\n  to/TO\n  1889/CD\n  by/IN\n  (GPE French/JJ)\n  engineer/NN\n  (PERSON Gustave/NNP Eiffel/NNP)\n  ,/,\n  whose/WP$\n  company/NN\n  specialized/VBD\n  in/IN\n  building/NN\n  metal/NN\n  frameworks/NNS\n  and/CC\n  structures/NNS\n  ./.)'
